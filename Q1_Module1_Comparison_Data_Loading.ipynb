# %% [markdown]
# # Module 1: Comparison of Memory-Based and Generator-Based Data Loading
# ### Question 1 (10 points)
# Compare memory-based data loading with generator-based loading. Demonstrate with sample code and discuss results.

# %%
# Imports
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## Memory-Based Data Loading
# Add your code and comments here.

# %% [markdown]
# ## Generator-Based Data Loading
# Add your code and comments here.

# %% [markdown]
# ## Comparison and Discussion
# Summarize the results and key differences.
